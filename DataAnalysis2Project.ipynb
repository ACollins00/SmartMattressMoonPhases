# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as nmpy

# %% [markdown]
# Feature 5: Annotate your code with markdown cells in Jupyter Notebook, write clear code comments, and have a well-written README.md. Tidy up your notebook, and make sure you don’t have any empty cells or incomplete cells that don’t do anything. Make sure it’s all functional before your final github commit.

# %% [markdown]
# Feature 4: Build a custom data dictionary and include it either in your README or as a separate document. This will only apply if your data set does not already have a data dictionary or if you’re building a custom data set.
#
# Note: Below demonstrates a custom data dictionary. A custom data dictionary is also included in a README on Github.

# %%
#Definitions of the terms used in graphs.

my_dictionary = {"TIME TO FALL ASLEEP: the amount of time in minutes to fall asleep", 
                 "RESTFUL: the amount of time in minutes spent in a restful state",
                 "RESTLESS: the amount of time in minutes spent in a restless state",
                 "HEART RATE: the frequency of heartbeats per minute",
                 "HEART RATE VARIABILITY: the amount of time between fluctuations of a heartbeat; this may reflect the body's response to stress",
                 "BREATH RATE: the number of breaths per minute",
                 "MOON PHASES: the monthly phases or cycles of the moon",
                 "MOON PHASES ARE ASSIGNED A NUMERICAL VALUE BASED ON THE PATICULAR PHASE IN ORDER TO SHOW ON A GRAPH. A VALUE OF 150 INDICATES THE MOON IS IN A NEW PHASE"}


print(my_dictionary)
# Out:
# {'RESTLESS: the amount of time in minutes spent in a restless state', "HEART RATE VARIABILITY: the amount of time between fluctuations of a heartbeat; this may reflect the body's response to stress", 'MOON PHASES: the monthly phases or cycles of the moon', 'RESTFUL: the amount of time in minutes spent in a restful state', 'TIME TO FALL ASLEEP: the amount of time in minutes to fall asleep', 'HEART RATE: the frequency of heartbeats per minute', 'MOON PHASES ARE ASSIGNED A NUMERICAL VALUE BASED ON THE PATICULAR PHASE IN ORDER TO SHOW ON A GRAPH. A VALUE OF 150 INDICATES THE MOON IS IN A NEW PHASE', 'BREATH RATE: the number of breaths per minute'}

# %% [markdown]
# Feature 1: Read TWO data files (JSON, CSV, Excel, etc.)
#
# Note: Below demonstrates reading one CSV data file. Reading a second CSV file will be demonstrated further down. After that, reading TWO CSV files together will be demonstrated. This project will show reading TWO CSV files separately AND together.

# %% [markdown]
# Feature 3: Make 3 matplotlib or seaborn (or another plotting library) visualizations to display your data.
#
# Note: Below demonstrates one matplotlib visualization. Further down there will be MORE THAN 3 matplotlib visualizations.

# %%
import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import drange
import numpy as np

df = pd.read_csv("SmartMattressStats - Sheet1 (2).csv")
print("Contents in csv file:", df)


plt.figure(figsize=(12,8))

plt.plot(df.Night, df.TtoFallAsleep, 'r.-', label="Time to Fall Asleep")
plt.plot(df.Night, df.Restful, 'b.-', label="Restful")
plt.plot(df.Night, df.Restless, 'y.-', label="Restless")
plt.legend(['Time to Fall Asleep', 'Restfull', 'Restless'])
plt.title("Sleep Quality Stats")
plt.suptitle("Graph 1")
plt.xlabel("Night")
plt.ylabel("Minutes")

plt.xticks(rotation='vertical')

plt.tick_params(axis='x', which='major', labelsize=6)

plt.tight_layout()

plt.show()
# Out:
# Contents in csv file:        Night  TtoFallAsleep  Restful  Restless
# 0   12/01/22             46      266        20
# 1   12/02/22              7      412        61
# 2   12/03/22             25      428        39
# 3   12/04/22              9      284        28
# 4   12/05/22              7      510        37
# ..       ...            ...      ...       ...
# 57  01/27/23            109      146        27
# 58  01/28/23              2      455        49
# 59  01/29/23              4      371        61
# 60  01/30/23            108      399        45
# 61  01/31/23             75      185        25
#
# [62 rows x 4 columns]

# %% [markdown]
# Feature 1: Read TWO data files (JSON, CSV, Excel, etc.)
#
# Note: Below demonstrates reading a SECOND CSV file. Reading two CSV files together will be demonstrated further down.

# %% [markdown]
# Feature 3: Make 3 matplotlib or seaborn (or another plotting library) visualizations to display your data.
#
# Note: A SECCOND Matplotlib visualization.

# %% [markdown]
# In the graph below, note the most active biometric is the HRV.

# %%
import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import drange
import numpy as np

df = pd.read_csv("HealthStats - Sheet1 (1).csv")
print("Contents in csv file:", df)

plt.figure(figsize=(14,10))

plt.plot(df.Night, df.HR, 'r.-', label="Heart Rate")
plt.plot(df.Night, df.HRV, 'b.-', label="HRV")
plt.plot(df.Night, df.BR, 'y.-', label="Breath Rate")
plt.legend(['HR', 'HRV', 'BR',])
plt.title("Health Stats")
plt.suptitle("Graph 2")
plt.xlabel("Night")
plt.ylabel("Minutes")

plt.xticks(rotation='vertical')

plt.tick_params(axis='x', which='major', labelsize=8)

plt.tight_layout()

plt.show()
# Out:
# Contents in csv file:        Night  HR  HRV  BR  Moon
# 0   12/01/22  60  140  14    10
# 1   12/02/22  71   69  14    10
# 2   12/03/22  75   73  12    10
# 3   12/04/22  76   46  15    10
# 4   12/05/22  63  124  14    10
# ..       ...  ..  ...  ..   ...
# 57  01/27/23  68   91  15    40
# 58  01/28/23  73   51  15   150
# 59  01/29/23  83   47  15    10
# 60  01/30/23  70   83  15    10
# 61  01/31/23  65  218  15    10
#
# [62 rows x 5 columns]

# %% [markdown]
# Feature 3: Make 3 matplotlib or seaborn (or another plotting library) visualizations to display your data.
#
# Note: A THIRD Matplotlib visualization which includes moon phases. The moon phases don't clearly depict a relationship to health stats, so a new graph will be demonstrated further down to show an interesting pattern.

# %%
import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import drange
import numpy as np

df = pd.read_csv("HealthStats - Sheet1 (1).csv")

plt.figure(figsize=(14,10))

plt.plot(df.Night, df.HR, 'r.-', label="Heart Rate")
plt.plot(df.Night, df.HRV, 'b.-', label="HRV")
plt.plot(df.Night, df.BR, 'y.-', label="Breath Rate")
plt.plot(df.Night, df.Moon, 'g.', label="Moon Phase")
plt.legend(['HR', 'HRV', 'BR', 'Moon Phase'])
plt.title("Health Stats with Moon Phases")
plt.suptitle("Graph 3")
plt.xlabel("Night")
plt.ylabel("Minutes")

plt.xticks(rotation='vertical')

plt.tick_params(axis='x', which='major', labelsize=8)

plt.tight_layout()

plt.show()

# %% [markdown]
# Feature 3: Make 3 matplotlib or seaborn (or another plotting library) visualizations to display your data.
#
# Note: Below demonstrates a FOURTH matplotlib visualization. Some information was removed to show a relationship between health stats and moon phases. It’s only slightly better, so a new graph will be demonstrated further down to make things clearer.

# %%
import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import drange
import numpy as np

df = pd.read_csv("HealthStats - Sheet1 (1).csv")

plt.figure(figsize=(14,10))

plt.plot(df.Night, df.HRV, 'b.-', label="HRV")
plt.plot(df.Night, df.Moon, 'g.', label="Moon Phase")
plt.legend(['HRV', 'Moon Phase'])
plt.title("HRV and Moon Phases")
plt.suptitle("Graph 4")
plt.xlabel("Night")
plt.ylabel("Minutes")

plt.xticks(rotation='vertical')

plt.tick_params(axis='x', which='major', labelsize=8)

plt.tight_layout()

plt.show()

# %%
df = pd.read_csv('SmartMattressStats - Sheet1.csv')
df.head()
# Out:
#    Night  TtoFallAsleep  Restful  Restless
# 0  12/01           46.0     4.26     20.00
# 1  12/02            7.0     6.52      1.01
# 2  12/03           25.0     7.08     39.00
# 3  12/04            9.0     4.44     28.00
# 4  12/05            7.0     8.30     37.00

# %%
to_drop = ['TtoFallAsleep']

df.drop(to_drop, inplace=True, axis=1)

df.head()
# Out:
#    Night  Restful  Restless
# 0  12/01     4.26     20.00
# 1  12/02     6.52      1.01
# 2  12/03     7.08     39.00
# 3  12/04     4.44     28.00
# 4  12/05     8.30     37.00

# %%
df = pd.read_csv("SmartMattressStats - Sheet1 (2).csv")
print("Contents in csv file:", df)

plt.figure(figsize=(12,8))

plt.plot(df.Night, df.Restful, 'b.-', label="Restful")
plt.plot(df.Night, df.Restless, 'y.-', label="Restless")
plt.legend(['Restfull', 'Restless'])
plt.title("Sleep Quality Stats")
plt.suptitle("Graph 5")
plt.xlabel("Night")
plt.ylabel("Minutes")

plt.xticks(rotation='vertical')

plt.tick_params(axis='x', which='major', labelsize=6)

plt.tight_layout()

plt.show()
# Out:
# Contents in csv file:        Night  TtoFallAsleep  Restful  Restless
# 0   12/01/22             46      266        20
# 1   12/02/22              7      412        61
# 2   12/03/22             25      428        39
# 3   12/04/22              9      284        28
# 4   12/05/22              7      510        37
# ..       ...            ...      ...       ...
# 57  01/27/23            109      146        27
# 58  01/28/23              2      455        49
# 59  01/29/23              4      371        61
# 60  01/30/23            108      399        45
# 61  01/31/23             75      185        25
#
# [62 rows x 4 columns]

# %%
plotdata = pd.read_csv("HealthStats - Sheet1 (1).csv")

plt.figure().set_figwidth(20)

plt.rcParams["figure.figsize"] = [12, 6]
plt.rcParams["figure.autolayout"] = True

plt.style.use("fivethirtyeight")
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# Feature 1: Read TWO data files (JSON, CSV, Excel, etc.)

# %% [markdown]
# Feature 2: Clean your data and perform a pandas merge with your two data sets, then calculate some new values based on the new data set.

# %%
#Executing for the purpose of showing all of the columns and rows before cleaning, merging, and calculating new value.
data1 = pd.read_csv('HealthStats - Sheet1 (1).csv')
data2= pd.read_csv('SmartMattressStats - Sheet1 (2).csv')

df = pd.merge(data1, data2,
         on='Night',
         how='outer')

print(df)
# Out:
#        Night  HR  HRV  BR  Moon  TtoFallAsleep  Restful  Restless
# 0   12/01/22  60  140  14    10             46      266        20
# 1   12/02/22  71   69  14    10              7      412        61
# 2   12/03/22  75   73  12    10             25      428        39
# 3   12/04/22  76   46  15    10              9      284        28
# 4   12/05/22  63  124  14    10              7      510        37
# ..       ...  ..  ...  ..   ...            ...      ...       ...
# 57  01/27/23  68   91  15    40            109      146        27
# 58  01/28/23  73   51  15   150              2      455        49
# 59  01/29/23  83   47  15    10              4      371        61
# 60  01/30/23  70   83  15    10            108      399        45
# 61  01/31/23  65  218  15    10             75      185        25
#
# [62 rows x 8 columns]

# %%
#Merging two data frames, cleaning via dropping all but one column, and calculating the average of restfull minutes.
data1 = pd.read_csv('HealthStats - Sheet1 (1).csv')
data2= pd.read_csv('SmartMattressStats - Sheet1 (2).csv')

df = pd.merge(data1, data2,
              on='Night',
              how='outer')

to_drop = ['TtoFallAsleep',
           'Restless',
           'Moon',
           'BR',
           'HRV',
           'HR']

df.drop(to_drop, inplace=True, axis=1)

column_averages = df.mean(numeric_only=True)

pd.set_option('display.max_rows', None)

df.head()

print(column_averages)
# Out:
# Restful    338.967742
# dtype: float64

# %%
#Just a reverse from code cell above (cleaning via dropping before merging.)
#Merging two data frames, cleaning via dropping all but one column, and calculating the average of restfull minutes.
data1 = pd.read_csv('HealthStats - Sheet1 (1).csv')
data2= pd.read_csv('SmartMattressStats - Sheet1 (2).csv')

to_drop = ['TtoFallAsleep',
           'Restless',
           'Moon',
           'BR',
           'HRV',
           'HR']

df = pd.merge(data1, data2,
              on='Night',
              how='outer')

df.drop(to_drop, inplace=True, axis=1)

column_averages = df.mean(numeric_only=True)

pd.set_option('display.max_rows', None)

df.head()

print(column_averages)
# Out:
# Restful    338.967742
# dtype: float64

# %%
#Showing the amount of lost sleep each night by adding the minutes spent falling asleep and being restless.
data1 = pd.read_csv('HealthStats - Sheet1 (1).csv')
data2= pd.read_csv('SmartMattressStats - Sheet1 (2).csv')

df = pd.merge(data1, data2,
              on='Night',
              how='outer')

to_drop = ['Restful',
           'Moon',
           'BR',
           'HRV',
           'HR']

df.drop(to_drop, inplace=True, axis=1)

pd.set_option('display.max_rows', None)

sum_columns = df['TtoFallAsleep'] + df['Restless']

df['Sum of Lost Sleep'] = sum_columns

print(df)
# Out:
#        Night  TtoFallAsleep  Restless  Sum of Lost Sleep
# 0   12/01/22             46        20                 66
# 1   12/02/22              7        61                 68
# 2   12/03/22             25        39                 64
# 3   12/04/22              9        28                 37
# 4   12/05/22              7        37                 44
# 5   12/06/22             14        54                 68
# 6   12/07/22             51        43                 94
# 7   12/08/22             61        59                120
# 8   12/09/22             54        27                 81
# 9   12/10/22              7        55                 62
# 10  12/11/22             21        31                 52
# 11  12/12/22             23        63                 86
# 12  12/13/22              3        46                 49
# 13  12/14/22             52        39                 91
# 14  12/15/22             61        53                114
# ...

# %%
#Showing the averages of each column.
data1 = pd.read_csv('HealthStats - Sheet1 (1).csv')
data2= pd.read_csv('SmartMattressStats - Sheet1 (2).csv')

df = pd.merge(data1, data2,
         on='Night',
         how='outer')

print(df)

column_averages = df.mean(numeric_only=True)

pd.set_option('display.max_rows', None)

print(column_averages)
# Out:
#        Night  HR  HRV  BR  Moon  TtoFallAsleep  Restful  Restless
# 0   12/01/22  60  140  14    10             46      266        20
# 1   12/02/22  71   69  14    10              7      412        61
# 2   12/03/22  75   73  12    10             25      428        39
# 3   12/04/22  76   46  15    10              9      284        28
# 4   12/05/22  63  124  14    10              7      510        37
# 5   12/06/22  76   97  15   150             14      477        54
# 6   12/07/22  73  134  15    20             51      351        43
# 7   12/08/22  70  167  15    20             61      348        59
# 8   12/09/22  74   66  15    20             54      271        27
# 9   12/10/22  76   85  15    20              7      495        55
# 10  12/11/22  72  158  15    20             21      303        31
# 11  12/12/22  65  140  15    20             23      365        63
# 12  12/13/22  69  156  14    20              3      460        46
# ...

# %% [markdown]
# In the graph below, there are only TWO aspects being shown in order to highlight the areas that appear to correlate. (As noted earlier, a new moon phase is set to a value of 150 in order to show on a graph.) Approximately two days before the moon enters a new phase, there is a sharp increase in heart rate variability. A few times the sharp increase happens a couple of days after the moon enters a new phase.

# %%
df = pd.read_csv('HealthStats - Sheet1 (1).csv')
df = pd.read_csv('SmartMattressStats - Sheet1 (2).csv')
print("Contents in csv file:", df)

df = pd.merge(data1, data2,
         on='Night',
         how='outer')


plt.figure(figsize=(12,8))

plt.plot(df.Night, df.HRV, 'b.-', label="HRV")
plt.plot(df.Night, df.Moon, 'y.-', label="New Moon Phase")
plt.legend(['HRV', 'New Moon Phase'])
plt.title("Heart Rate Variability and Moon Phase Change")
plt.suptitle("Graph 7")
plt.xlabel("Night")
plt.ylabel("Minutes")

plt.xticks(rotation='vertical')

plt.tick_params(axis='x', which='major', labelsize=6)

plt.tight_layout()

plt.show()
# Out:
# Contents in csv file:        Night  TtoFallAsleep  Restful  Restless
# 0   12/01/22             46      266        20
# 1   12/02/22              7      412        61
# 2   12/03/22             25      428        39
# 3   12/04/22              9      284        28
# 4   12/05/22              7      510        37
# 5   12/06/22             14      477        54
# 6   12/07/22             51      351        43
# 7   12/08/22             61      348        59
# 8   12/09/22             54      271        27
# 9   12/10/22              7      495        55
# 10  12/11/22             21      303        31
# 11  12/12/22             23      365        63
# 12  12/13/22              3      460        46
# 13  12/14/22             52      277        39
# 14  12/15/22             61      373        53
# 15  12/16/22              5      383        65
# 16  12/17/22             15      425        60
# 17  12/18/22             53       68         9
# ...

# %% [markdown]
# Pay special attention to the moon phase at 150. This is when the moon has entered into a new phase. Note the HRV rises sharply 1-2 days before or after a new phase is beginning. In the span of 2 months (8 new moon phases) it doesn’t appear to be a coincidence. The activity of the moon does appear to have an influence on our biometrics-most notable, the HRV (heart rate variability) in this analysis.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('HealthStats - Sheet1 (1).csv')
fig, ax = plt.subplots(figsize=(14, 12))
ax.scatter(x = df['Night'], y = df['HRV'])
ax.scatter(x = df['Night'], y = df['Moon'])
plt.legend(['HRV', 'New Moon Phase'])
plt.xlabel("Night")
plt.xticks(rotation='vertical')


plt.show()
